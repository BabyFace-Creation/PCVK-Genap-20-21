# %% [markdown]
# <a href="https://colab.research.google.com/github/BabyFace-Creation/PCVK-Genap-20-21/blob/main/Jobsheet2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten01.jpg')

plt.imshow(img)

# %%
img2 = cv.cvtColor(img, cv.COLOR_BGR2RGB)

plt.imshow(img2)

# %%
black_img2 = np.zeros(shape = (512,512,3), dtype = np.int32)
plt.imshow(black_img2)

vertices = np.array([[100,400], [0,500], [200,500]], dtype = np.int32)
vertices

pts = vertices.reshape((-1,1,2))
pts

cv.polylines(black_img2, [pts], isClosed=True, color=(255,0,0), thickness = 5)
plt.imshow(black_img2)

# %%
img3 = img2



vertices = np.array([[100,500], [0,600], [200,600]], dtype = np.int32)
vertices

pts = vertices.reshape((-1,1,2))
pts

cv.polylines(img3, [pts], isClosed=True, color=(255,0,0), thickness = 5)
plt.imshow(img3)

# %%
img5 = img
img5 = cv.cvtColor(img, cv.COLOR_BGR2RGB)



s1 = img5[10:100, 10:100]
plt.imshow(s1)

# %%
img6 = img
img6 = cv.cvtColor(img, cv.COLOR_BGR2RGB)



s2 = img6[5:30, :]
plt.imshow(s2)

# %%
img7 = img
img7 = cv.cvtColor(img, cv.COLOR_BGR2RGB)

img7[:,:,0] = np.zeros([img7.shape[0],img7.shape[1]])

plt.imshow(img7)

# %%
img7 = img
img7 = cv.cvtColor(img, cv.COLOR_BGR2RGB)

vertices = np.array([[400,80], [300,250], [500,250]], dtype = np.int32)
vertices

pts = vertices.reshape((-1,1,2))
pts

cv.polylines(img7, [pts], isClosed=True, color=(255,0,0), thickness = 5)

cv.circle(img7,center = (400,200), radius = 100, color = (0,0,255), thickness = 5)

cv.rectangle(img7, pt1=(200,100), pt2=(550,300), color = (0,255,0), thickness = 5)

plt.imshow(img7)

# %%
img8 = img

plt.imshow(img8)
